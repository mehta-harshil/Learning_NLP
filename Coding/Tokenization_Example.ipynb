# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in ./.venv/lib/python3.10/site-packages (3.9.4)
# Requirement already satisfied: click in ./.venv/lib/python3.10/site-packages (from nltk) (8.3.3)
# Requirement already satisfied: joblib in ./.venv/lib/python3.10/site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in ./.venv/lib/python3.10/site-packages (from nltk) (2026.4.4)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.10/site-packages (from nltk) (4.67.3)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /home/harshil/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/harshil/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
corpus = """My name is Mehta Harshil and I am persuing my bachlore’s degree in SSGEC college. I want to become Robotics Engineer.
"""

# %%
print(corpus)
# Out:
# My name is Mehta Harshil and I am persuing my bachlore’s degree in SSGEC college. I want to become Robotics Engineer.

# %% [markdown]
# ### Tokenization
# ### Paragraph - > Sentence

# %%
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ['My name is Mehta Harshil and I am persuing my bachlore’s degree in SSGEC college.',
#  'I want to become Robotics Engineer.']

# %% [markdown]
# ## Tokenization
# ## Paragraph -->  Words
# ## Sentence --> Words

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize import wordpunct_tokenize
from nltk.tokenize import TreebankWordTokenizer

# %%
from nltk.tokenize import word_tokenize


words1 = word_tokenize(corpus)
print(words1)


words2 = wordpunct_tokenize(corpus)
print(words2)

tokenizer = TreebankWordTokenizer()
word3 = tokenizer.tokenize(corpus)
print(word3)
# Out:
# ['My', 'name', 'is', 'Mehta', 'Harshil', 'and', 'I', 'am', 'persuing', 'my', 'bachlore', '’', 's', 'degree', 'in', 'SSGEC', 'college', '.', 'I', 'want', 'to', 'become', 'Robotics', 'Engineer', '.']
# ['My', 'name', 'is', 'Mehta', 'Harshil', 'and', 'I', 'am', 'persuing', 'my', 'bachlore', '’', 's', 'degree', 'in', 'SSGEC', 'college', '.', 'I', 'want', 'to', 'become', 'Robotics', 'Engineer', '.']
# ['My', 'name', 'is', 'Mehta', 'Harshil', 'and', 'I', 'am', 'persuing', 'my', 'bachlore’s', 'degree', 'in', 'SSGEC', 'college.', 'I', 'want', 'to', 'become', 'Robotics', 'Engineer', '.']
