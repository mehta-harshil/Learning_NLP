# %% [markdown]
# # Stemming

# %% [markdown]
# ## PorterStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
words = ["eating","eats","eaten","writing","writes","programming","programs","testing","applied","Congratualations"]

for word in words:
    print(word, " ---> ",stemming.stem(word))
# Out:
# eating  --->  eat
# eats  --->  eat
# eaten  --->  eaten
# writing  --->  write
# writes  --->  write
# programming  --->  program
# programs  --->  program
# testing  --->  test
# applied  --->  appli
# Congratualations  --->  congratual

# %% [markdown]
# ## RegxpStemmer

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
r
